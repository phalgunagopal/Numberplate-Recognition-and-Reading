# %% [markdown]
# ## 0. Install and Import Dependencies

# %%
# !pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu113
# !pip install easyocr
# !pip install imutils
# Out:
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu113
# Requirement already satisfied: torch in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (1.11.0)
# Requirement already satisfied: torchvision in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (0.12.0)
# Requirement already satisfied: torchaudio in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (0.11.0+cu113)
# Requirement already satisfied: typing-extensions in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from torch) (3.10.0.2)
# Requirement already satisfied: numpy in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from torchvision) (1.21.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from torchvision) (8.4.0)
# Requirement already satisfied: requests in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from torchvision) (2.26.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision) (1.26.6)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision) (2.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision) (2021.5.30)
# Requirement already satisfied: easyocr in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (1.5.0)
# Requirement already satisfied: torch in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (1.11.0)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (4.1.2.30)
# Requirement already satisfied: scipy in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (1.7.2)
# Requirement already satisfied: torchvision>=0.5 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (0.12.0)
# Requirement already satisfied: python-bidi in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: PyYAML in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: Pillow in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (8.4.0)
# Requirement already satisfied: numpy in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (1.21.4)
# Requirement already satisfied: scikit-image in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from easyocr) (0.19.3)
# Requirement already satisfied: requests in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from torchvision>=0.5->easyocr) (2.26.0)
# Requirement already satisfied: typing-extensions in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from torchvision>=0.5->easyocr) (3.10.0.2)
# Requirement already satisfied: six in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from scikit-image->easyocr) (2.19.3)
# Requirement already satisfied: networkx>=2.2 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from scikit-image->easyocr) (2.6.3)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from scikit-image->easyocr) (21.2)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from scikit-image->easyocr) (2021.11.2)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (2.4.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2021.5.30)
# Requirement already satisfied: charset-normalizer~=2.0.0 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.0.9)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.6)
# Requirement already satisfied: imutils in c:\users\phalg\pycharmprojects\datascienceint\venv\lib\site-packages (0.5.4)

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np
import imutils
import easyocr

# %% [markdown]
# ## 1. Read in Image, Grayscale and Blur

# %%
img = cv2.imread('image5.jpeg')
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 2. Apply filter and find edges for localization

# %%
bfilter = cv2.bilateralFilter(gray, 11, 17, 17) #Noise reduction
edged = cv2.Canny(bfilter, 30, 200,apertureSize=3) #Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 3. Find Contours and Apply Mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
contours = imutils.grab_contours(keypoints)
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[ 996,  913]],
#
#        [[1105,  906]],
#
#        [[1108,  954]],
#
#        [[1002,  960]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask)

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## 4. Use Easy OCR To Read Text

# %%
reader = easyocr.Reader(['en'])
result = reader.readtext(cropped_image)
result
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[2, 16], [110, 16], [110, 40], [2, 40]],
#   'KA 6G1 AJ 0872',
#   0.36413596189444425)]

# %% [markdown]
# ## 5. Render Result

# %%
text = result[0][-2]
font = cv2.FONT_HERSHEY_SIMPLEX
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))
